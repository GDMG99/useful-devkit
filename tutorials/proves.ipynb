# %%
import sys
sys.path.append(r'/n/fs/pci-sharedt/gd3828/workspace/useful-devkit/src/useful')
from useful import USEFUL
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
usfl = USEFUL('v0.6.1', '/n/fs/pci-sharedt/gd3828/workspace/gen-detect/data/USEFUL')
# Out:
# Starting to load log...
# Finished loading log! (0.000 s)
# **********
# Starting to load calibrated_sensor...
# Finished loading calibrated_sensor! (0.000 s)
# **********
# Starting to load map...
# map.json not found
# Finished loading map! (0.000 s)
# **********
# Starting to load sensor...
# Finished loading sensor! (0.000 s)
# **********
# Starting to load sample...
# Finished loading sample! (0.019 s)
# **********
# Starting to load scene...
# Finished loading scene! (0.000 s)
# **********
# Starting to load sample_data...
# Finished loading sample_data! (0.284 s)
# **********
# Starting to load sample_annotation...
# Finished loading sample_annotation! (0.678 s)
# **********
# Starting to load sample_annotation_2d...
# Finished loading sample_annotation_2d! (2.902 s)
# **********
# Starting to load instance...
# Finished loading instance! (0.044 s)
# **********
# Starting to load category...
# Finished loading category! (0.000 s)
# **********
# Starting to load visibility...
# ...

# %%
usfl.render_sample_data(usfl.sample[0]['data']['WIDE_LEFT'])
